# %%
import numpy as np
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

# %%
new_df = pd.read_excel("4aFeaturesAsap.xlsx")

# %%
new_df.groupby('ai_generated').count()
# Out:
#               Unnamed: 0.1  Unnamed: 0  essay_id  essay_set  essay  ai_llm  \
# ai_generated
# 0                    21450       21450     21450      21450  21450   21450
# 1                    21680       21680     21680      21680  21680   21680
#
#               word_tokens  sentence_tokens  lemmatized_word_tokens  \
# ai_generated
# 0                   21450            21450                   21450
# 1                   21680            21680                   21680
#
#               total_word_count  ...  avg_adjectives_per_sentence  \
# ai_generated                    ...
# 0                        21450  ...                        21450
# 1                        21680  ...                        21680
#
#               avg_adverbs_per_sentence  avg_verbs_per_sentence  \
# ai_generated
# 0                                21450                   21450
# 1                                21680                   21680
#
#               avg_nouns_per_sentence      0  flesch_reading_ease  \
# ai_generated
# 0                              21450  21450                21450
# 1                              21680  21680                21680
#
#               flesch_kincaid_grade_level  smog_index  sentiment_polarity  \
# ai_generated
# 0                                  21450       21450               21450
# 1                                  21680       21680               21680
#
#               sentiment.subjectivity
# ai_generated
# 0                              21450
# 1                              21680
#
# [2 rows x 32 columns]

# %%
new_df
# Out:
#        Unnamed: 0.1  Unnamed: 0  essay_id  essay_set  \
# 0                 0           0         1          1
# 1                 1           1         2          1
# 2                 2           2         3          1
# 3                 3           3         4          1
# 4                 4           4         5          1
# ...             ...         ...       ...        ...
# 43125         43125       43127       213          1
# 43126         43126       43128       214          1
# 43127         43127       43129       215          1
# 43128         43128       43130       216          1
# 43129         43129       43131       217          1
#
#                                                    essay            ai_llm  \
# 0      Dear local newspaper, I think effects computer...   human-generated
# 1      Dear @CAPS1 @CAPS2, I believe that using compu...   human-generated
# 2      Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...   human-generated
# 3      Dear Local Newspaper, @CAPS1 I have found that...   human-generated
# 4      Dear @LOCATION1, I know having computers has a...   human-generated
# ...                                                  ...               ...
# 43125  \n\nDear Editor, \n\nAs a citizen of this comm...  text-davinci-003
# 43126  \n\n\nDear Editor,\n\nAs a concerned citizen a...  text-davinci-003
# 43127  \n\nDear Editor,\n\nI am writing to share my o...  text-davinci-003
# 43128  \n\nTo the Editor: \n\nAs our world has become...  text-davinci-003
# 43129  \n\nDear Editor, \n\nI am writing to present m...  text-davinci-003
#
#        ai_generated                                        word_tokens  \
# 0                 0  ['dear', 'local', 'newspaper', 'think', 'effec...
# 1                 0  ['dear', 'caps1', 'caps2', 'believe', 'using',...
# 2                 0  ['dear', 'caps1', 'caps2', 'caps3', 'people', ...
# 3                 0  ['dear', 'local', 'newspaper', 'caps1', 'found...
# 4                 0  ['dear', 'location1', 'know', 'computers', 'po...
# ...             ...                                                ...
# 43125             1  ['dear', 'editor', 'citizen', 'community', 'fe...
# 43126             1  ['dear', 'editor', 'concerned', 'citizen', 'lo...
# 43127             1  ['dear', 'editor', 'writing', 'share', 'opinio...
# 43128             1  ['editor', 'world', 'become', 'increasingly', ...
# 43129             1  ['dear', 'editor', 'writing', 'present', 'thou...
#
#                                          sentence_tokens  \
# 0      ['dear local newspaper, i think effects comput...
# 1      ['dear @caps1 @caps2, i believe that using com...
# 2      ['dear, @caps1 @caps2 @caps3 more and more peo...
# 3      ['dear local newspaper, @caps1 i have found th...
# 4      ['dear @location1, i know having computers has...
# ...                                                  ...
# 43125  ["\n\ndear editor, \n\nas a citizen of this co...
# 43126  ['\n\n\ndear editor,\n\nas a concerned citizen...
# 43127  ['\n\ndear editor,\n\ni am writing to share my...
# 43128  ['\n\nto the editor: \n\nas our world has beco...
# 43129  ['\n\ndear editor, \n\ni am writing to present...
#
#                                   lemmatized_word_tokens  ...  \
# 0      ['dear', 'local', 'newspaper', 'think', 'effec...  ...
# 1      ['dear', 'caps1', 'caps2', 'believe', 'using',...  ...
# 2      ['dear', 'caps1', 'caps2', 'caps3', 'people', ...  ...
# 3      ['dear', 'local', 'newspaper', 'caps1', 'found...  ...
# 4      ['dear', 'location1', 'know', 'computer', 'pos...  ...
# ...                                                  ...  ...
# 43125  ['dear', 'editor', 'citizen', 'community', 'fe...  ...
# 43126  ['dear', 'editor', 'concerned', 'citizen', 'lo...  ...
# 43127  ['dear', 'editor', 'writing', 'share', 'opinio...  ...
# 43128  ['editor', 'world', 'become', 'increasingly', ...  ...
# 43129  ['dear', 'editor', 'writing', 'present', 'thou...  ...
#
#        avg_adjectives_per_sentence  avg_adverbs_per_sentence  \
# 0                         1.250000                  1.437500
# 1                         1.050000                  0.900000
# 2                         1.357143                  1.071429
# 3                         1.925926                  1.074074
# 4                         1.000000                  1.266667
# ...                            ...                       ...
# 43125                     1.833333                  1.166667
# 43126                     2.250000                  0.750000
# 43127                     1.500000                  0.583333
# 43128                     2.250000                  1.166667
# 43129                     1.562500                  1.125000
#
#        avg_verbs_per_sentence  avg_nouns_per_sentence  0  flesch_reading_ease  \
# 0                    4.250000                5.250000  1                74.02
# 1                    4.250000                5.700000  1                67.08
# 2                    3.785714                6.142857  0                68.20
# 3                    3.629630                7.407407  4                60.24
# 4                    2.900000                3.866667  1                72.66
# ...                       ...                     ... ..                  ...
# 43125                3.500000                5.166667  0                42.51
# 43126                2.416667                5.833333  1                44.75
# 43127                3.166667                5.000000  0                38.72
# 43128                4.500000                5.750000  2                32.53
# 43129                2.687500                4.250000  1                46.27
#
#       flesch_kincaid_grade_level smog_index sentiment_polarity  \
# 0                              9       10.2           0.310471
# 1                             10       11.6           0.274000
# 2                              9       12.0           0.340393
# 3                              8       12.3           0.266828
# 4                              8       11.1           0.199684
# ...                          ...        ...                ...
# 43125                         14       15.6           0.281250
# 43126                         12       14.2           0.190260
# 43127                         12       14.6           0.197683
# 43128                         15       16.1           0.297464
# 43129                         11       14.6           0.098737
#
#        sentiment.subjectivity
# 0                    0.385613
# 1                    0.613167
# 2                    0.498657
# 3                    0.441795
# 4                    0.485814
# ...                       ...
# 43125                0.780208
# 43126                0.500250
# 43127                0.468450
# 43128                0.521480
# 43129                0.410249
#
# [43130 rows x 33 columns]

# %%
#Removing Special Charactes
new_df["Remove_Special_Characters"]=new_df["essay"].str.replace('\W', ' ', regex=True)
new_df_R=new_df["Remove_Special_Characters"]
new_df_R
# Out:
# 0        Dear local newspaper  I think effects computer...
# 1        Dear  CAPS1  CAPS2  I believe that using compu...
# 2        Dear   CAPS1  CAPS2  CAPS3 More and more peopl...
# 3        Dear Local Newspaper   CAPS1 I have found that...
# 4        Dear  LOCATION1  I know having computers has a...
#                                ...
# 43125      Dear Editor    As a citizen of this communit...
# 43126       Dear Editor   As a concerned citizen and lo...
# 43127      Dear Editor   I am writing to share my opini...
# 43128      To the Editor    As our world has become inc...
# 43129      Dear Editor    I am writing to present my th...
# Name: Remove_Special_Characters, Length: 43130, dtype: object

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# lemmatization is a lot more powerful. It looks beyond word reduction and considers a language’s full vocabulary to
# apply a morphological analysis to words, aiming to remove inflectional endings only and to return the base or
# dictionary form of a word
# Wordnet is a publicly available lexical database of over 200 languages that provides semantic relationships betweenits words

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
lemmatizer = nltk.stem.WordNetLemmatizer()
wordnet_lemmatizer = WordNetLemmatizer()
stop = stopwords.words('english')


def nltk_tag_to_wordnet_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

def lemmatize_sentence(new_df_R):
    #tokenize the sentence and find the POS tag for each token
    nltk_tagged = nltk.pos_tag(nltk.word_tokenize(new_df_R))
    #tuple of (token, wordnet_tag)
    wordnet_tagged = map(lambda x: (x[0], nltk_tag_to_wordnet_tag(x[1])), nltk_tagged)
    lemmatized_sentence = []
    for word, tag in wordnet_tagged:
        if tag is None:
            #if there is no available tag, append the token as is
            lemmatized_sentence.append(word)
        else:
            #else use the tag to lemmatize the token
            lemmatized_sentence.append(lemmatizer.lemmatize(word, tag))
    return " ".join(lemmatized_sentence)

# Lemmatizing
new_df["Lemmatizing"] = new_df_R.apply(lambda x: lemmatize_sentence(x))

# %%
#The words which are generally filtered out before processing a natural language are called stop words
#Examples of a few stop words in English are “the”, “a”, “an”, “so”, “what”.
#NLTK is a library to play with natural language.The steps to import the library and the English stop words list
from nltk.corpus import stopwords
stop = stopwords.words('english')

# Exclude stopwords with Python's list comprehension and pandas.DataFrame.apply.
new_df['without_stopwords'] = new_df["Lemmatizing"].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
print(new_df['without_stopwords'][1])
print("Old length: ", len(new_df["Lemmatizing"][1]))
print("New length: ", len(new_df['without_stopwords'][1]))
# Out:
# Dear CAPS1 CAPS2 I believe use computer benefit us many way like talk become friend others website like facebook mysace Using computer help us find coordibates location able ourselfs million information Also computer benefit us help job plan house plan type NUM1 page report one job less write Now let go wonder world technology Using computer help us life talk make friend line Many people myspace facebooks aim benefit us conversation one another Many people believe computer bad make friend never talk I fortunate computer help school work social life I make friend Computers help us find location coordibates million information online If go internet lot know go onto website MONTH1 help us location coordinate like LOCATION1 Would rather use computer LOCATION3 When suppose vacation LOCATION2 Million information find internet You almost every question computer Would rather easily draw house plan computer take NUM1 hour one hand ugly erazer mark garrenteed find job draw like Also appling job many worker must write long paper like NUM3 word essay job fit many people I know like write NUM3 word non stopp hour could take I hav computer That computer need lot adays I hope essay impact descion computer great machine work The day I show mom use computer say great invention sense slice bread Now go buy computer help chat online friend find location million information one click button help self get job neat prepare printed work bos love
# Old length:  2148
# New length:  1446

# %%
new_df['ai_generated'] = new_df['ai_generated'].replace([0,1],['Human-Generated', 'Ai-Generated'])
new_df['ai_generated']
# Out:
# 0        Human-Generated
# 1        Human-Generated
# 2        Human-Generated
# 3        Human-Generated
# 4        Human-Generated
#               ...
# 43125       Ai-Generated
# 43126       Ai-Generated
# 43127       Ai-Generated
# 43128       Ai-Generated
# 43129       Ai-Generated
# Name: ai_generated, Length: 43130, dtype: object

# %%
new_df.groupby('ai_generated').count()
# Out:
#                  Unnamed: 0.1  Unnamed: 0  essay_id  essay_set  essay  ai_llm  \
# ai_generated
# Ai-Generated            21680       21680     21680      21680  21680   21680
# Human-Generated         21450       21450     21450      21450  21450   21450
#
#                  word_tokens  sentence_tokens  lemmatized_word_tokens  \
# ai_generated
# Ai-Generated           21680            21680                   21680
# Human-Generated        21450            21450                   21450
#
#                  total_word_count  ...  avg_nouns_per_sentence      0  \
# ai_generated                       ...
# Ai-Generated                21680  ...                   21680  21680
# Human-Generated             21450  ...                   21450  21450
#
#                  flesch_reading_ease  flesch_kincaid_grade_level  smog_index  \
# ai_generated
# Ai-Generated                   21680                       21680       21680
# Human-Generated                21450                       21450       21450
#
#                  sentiment_polarity  sentiment.subjectivity  \
# ai_generated
# Ai-Generated                  21680                   21680
# Human-Generated               21450                   21450
#
#                  Remove_Special_Characters  Lemmatizing  without_stopwords
# ai_generated
# Ai-Generated                         21680        21680              21680
# Human-Generated                      21450        21450              21450
#
# [2 rows x 35 columns]

# %%
new_df.to_csv('essay_data.csv', index=False)

# %%
# Seperate the features, X,  from the target variable, y
y = new_df['ai_generated']
X = new_df['without_stopwords']

# %%
new_df
# Out:
#        Unnamed: 0.1  Unnamed: 0  essay_id  essay_set  \
# 0                 0           0         1          1
# 1                 1           1         2          1
# 2                 2           2         3          1
# 3                 3           3         4          1
# 4                 4           4         5          1
# ...             ...         ...       ...        ...
# 43125         43125       43127       213          1
# 43126         43126       43128       214          1
# 43127         43127       43129       215          1
# 43128         43128       43130       216          1
# 43129         43129       43131       217          1
#
#                                                    essay            ai_llm  \
# 0      Dear local newspaper, I think effects computer...   human-generated
# 1      Dear @CAPS1 @CAPS2, I believe that using compu...   human-generated
# 2      Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...   human-generated
# 3      Dear Local Newspaper, @CAPS1 I have found that...   human-generated
# 4      Dear @LOCATION1, I know having computers has a...   human-generated
# ...                                                  ...               ...
# 43125  \n\nDear Editor, \n\nAs a citizen of this comm...  text-davinci-003
# 43126  \n\n\nDear Editor,\n\nAs a concerned citizen a...  text-davinci-003
# 43127  \n\nDear Editor,\n\nI am writing to share my o...  text-davinci-003
# 43128  \n\nTo the Editor: \n\nAs our world has become...  text-davinci-003
# 43129  \n\nDear Editor, \n\nI am writing to present m...  text-davinci-003
#
#           ai_generated                                        word_tokens  \
# 0      Human-Generated  ['dear', 'local', 'newspaper', 'think', 'effec...
# 1      Human-Generated  ['dear', 'caps1', 'caps2', 'believe', 'using',...
# 2      Human-Generated  ['dear', 'caps1', 'caps2', 'caps3', 'people', ...
# 3      Human-Generated  ['dear', 'local', 'newspaper', 'caps1', 'found...
# 4      Human-Generated  ['dear', 'location1', 'know', 'computers', 'po...
# ...                ...                                                ...
# 43125     Ai-Generated  ['dear', 'editor', 'citizen', 'community', 'fe...
# 43126     Ai-Generated  ['dear', 'editor', 'concerned', 'citizen', 'lo...
# 43127     Ai-Generated  ['dear', 'editor', 'writing', 'share', 'opinio...
# 43128     Ai-Generated  ['editor', 'world', 'become', 'increasingly', ...
# 43129     Ai-Generated  ['dear', 'editor', 'writing', 'present', 'thou...
#
#                                          sentence_tokens  \
# 0      ['dear local newspaper, i think effects comput...
# 1      ['dear @caps1 @caps2, i believe that using com...
# 2      ['dear, @caps1 @caps2 @caps3 more and more peo...
# 3      ['dear local newspaper, @caps1 i have found th...
# 4      ['dear @location1, i know having computers has...
# ...                                                  ...
# 43125  ["\n\ndear editor, \n\nas a citizen of this co...
# 43126  ['\n\n\ndear editor,\n\nas a concerned citizen...
# 43127  ['\n\ndear editor,\n\ni am writing to share my...
# 43128  ['\n\nto the editor: \n\nas our world has beco...
# 43129  ['\n\ndear editor, \n\ni am writing to present...
#
#                                   lemmatized_word_tokens  ...  \
# 0      ['dear', 'local', 'newspaper', 'think', 'effec...  ...
# 1      ['dear', 'caps1', 'caps2', 'believe', 'using',...  ...
# 2      ['dear', 'caps1', 'caps2', 'caps3', 'people', ...  ...
# 3      ['dear', 'local', 'newspaper', 'caps1', 'found...  ...
# 4      ['dear', 'location1', 'know', 'computer', 'pos...  ...
# ...                                                  ...  ...
# 43125  ['dear', 'editor', 'citizen', 'community', 'fe...  ...
# 43126  ['dear', 'editor', 'concerned', 'citizen', 'lo...  ...
# 43127  ['dear', 'editor', 'writing', 'share', 'opinio...  ...
# 43128  ['editor', 'world', 'become', 'increasingly', ...  ...
# 43129  ['dear', 'editor', 'writing', 'present', 'thou...  ...
#
#        avg_nouns_per_sentence  0  flesch_reading_ease  \
# 0                    5.250000  1                74.02
# 1                    5.700000  1                67.08
# 2                    6.142857  0                68.20
# 3                    7.407407  4                60.24
# 4                    3.866667  1                72.66
# ...                       ... ..                  ...
# 43125                5.166667  0                42.51
# 43126                5.833333  1                44.75
# 43127                5.000000  0                38.72
# 43128                5.750000  2                32.53
# 43129                4.250000  1                46.27
#
#        flesch_kincaid_grade_level  smog_index  sentiment_polarity  \
# 0                               9        10.2            0.310471
# 1                              10        11.6            0.274000
# 2                               9        12.0            0.340393
# 3                               8        12.3            0.266828
# 4                               8        11.1            0.199684
# ...                           ...         ...                 ...
# 43125                          14        15.6            0.281250
# 43126                          12        14.2            0.190260
# 43127                          12        14.6            0.197683
# 43128                          15        16.1            0.297464
# 43129                          11        14.6            0.098737
#
#       sentiment.subjectivity  \
# 0                   0.385613
# 1                   0.613167
# 2                   0.498657
# 3                   0.441795
# 4                   0.485814
# ...                      ...
# 43125               0.780208
# 43126               0.500250
# 43127               0.468450
# 43128               0.521480
# 43129               0.410249
#
#                                Remove_Special_Characters  \
# 0      Dear local newspaper  I think effects computer...
# 1      Dear  CAPS1  CAPS2  I believe that using compu...
# 2      Dear   CAPS1  CAPS2  CAPS3 More and more peopl...
# 3      Dear Local Newspaper   CAPS1 I have found that...
# 4      Dear  LOCATION1  I know having computers has a...
# ...                                                  ...
# 43125    Dear Editor    As a citizen of this communit...
# 43126     Dear Editor   As a concerned citizen and lo...
# 43127    Dear Editor   I am writing to share my opini...
# 43128    To the Editor    As our world has become inc...
# 43129    Dear Editor    I am writing to present my th...
#
#                                              Lemmatizing  \
# 0      Dear local newspaper I think effect computer h...
# 1      Dear CAPS1 CAPS2 I believe that use computer w...
# 2      Dear CAPS1 CAPS2 CAPS3 More and more people us...
# 3      Dear Local Newspaper CAPS1 I have find that ma...
# 4      Dear LOCATION1 I know have computer have a pos...
# ...                                                  ...
# 43125  Dear Editor As a citizen of this community I f...
# 43126  Dear Editor As a concerned citizen and long ti...
# 43127  Dear Editor I be write to share my opinion on ...
# 43128  To the Editor As our world have become increas...
# 43129  Dear Editor I be write to present my thought o...
#
#                                        without_stopwords
# 0      Dear local newspaper I think effect computer p...
# 1      Dear CAPS1 CAPS2 I believe use computer benefi...
# 2      Dear CAPS1 CAPS2 CAPS3 More people use compute...
# 3      Dear Local Newspaper CAPS1 I find many expert ...
# 4      Dear LOCATION1 I know computer positive effect...
# ...                                                  ...
# 43125  Dear Editor As citizen community I feel import...
# 43126  Dear Editor As concerned citizen long time res...
# 43127  Dear Editor I write share opinion effect compu...
# 43128  To Editor As world become increasingly reliant...
# 43129  Dear Editor I write present thought effect com...
#
# [43130 rows x 36 columns]

# %%
# Seperate the features, X,  from the target variable, y
y = new_df['ai_generated']
X = new_df['without_stopwords']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Builds a dictionary of features and transforms documents to feature vectors and convert our text documents to a
# matrix of token counts (CountVectorizer)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)

# When use tf.fit_transform() on your test / new data,
# it extracts a new vocabulary based on the words in your test data which are likely different
# than your training data.

# transform a count matrix to a normalized tf-idf representation (tf-idf transformer)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
import pickle

# %%
#Save vectorizer.vocabulary_
pickle.dump(count_vect.vocabulary_,open("feature.pkl","wb"))

# %%
#Load it later
loaded_vec = CountVectorizer(decode_error="replace",vocabulary=pickle.load(open("feature.pkl", "rb")))

# %%
# Dump the file
pickle.dump(tfidf_transformer, open("tfidf1.pkl", "wb"))

# %%
#Load it later
loaded_tfidf = pickle.load(open("tfidf1.pkl", 'rb'))

# %%
knn = KNeighborsClassifier(n_neighbors=2)

# training our classifier ; new_df['essay'] will be having numbers assigned for each category in train data
clf = knn.fit(X_train_tfidf,y_train)

# %%
import pickle

# save the iris classification model as a pickle file
model_pkl_file = "lassifier_model.pkl"

with open(model_pkl_file, 'wb') as file:
    pickle.dump(clf, file)

# %%
#Ai-generated
#docs_new = ['Technology has revolutionized various aspects of our lives, and one domain that has witnessed significant transformation is education. The integration of technology in educational settings has redefined the learning experience, enhancing access to information, fostering interactive engagement, and promoting personalized instruction. In this essay, we will explore the profound impact of technology on education, including its role in expanding educational opportunities, improving teaching methods, and preparing students for the demands of the 21st century']
#human-generated
docs_new = ['Many thing affect cyclist story The heat rlack water hill wild life affect The heat cause cyclist become right head grow realization I could drop heatstroke He hot cyclist afraid heatstroke make sure mirage The heat also affect visibility thinking Whe first saw factory worry mirage see thing Also lack water make dehydrate It make body hard function I ease past try keep balance dehydrated state The lack water make hard ride bike That smoky blue tune rattle around dry honey comb deteriorate brain The heat lack water make hard think straight The deserted desert impare situation He lose one help barren wasteland If people around could ask help In end setting break find filth bait shop The featured setting help hinder cyclist journey']
# building up feature vector of our input to chat with friends/new people
X_new_counts = loaded_vec.transform(docs_new)
# We call transform instead of fit_transform because it's already been fit
X_new_tfidf = loaded_tfidf.transform(X_new_counts)

# %%
predicted=clf.predict(X_new_tfidf)
print(predicted)
# Out:
# ['Human-Generated']
